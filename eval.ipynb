# %% [markdown]
# # Model Evaluation

# %%
# ----------------------------
# IMPORT STATEMENTS
# ----------------------------
import os
import csv
import librosa

import numpy as np
import matplotlib.pyplot as plt

from scipy import signal
from scipy.stats import norm
from scipy.io.wavfile import read
from IPython.display import Audio
from sklearn.model_selection import train_test_split

# %%
# ----------------------------
# CONSTANTS
# ----------------------------

HOP_LENGTH = 512
FRAME_LENGTH = 1024

# %%
# ----------------------------
# FUNCTION DEFINITIONS
# ----------------------------

def novelty(x, hop_length, frame_length):
    """Calculate the novelty function of an audio signal"""

    # Convert multi-channel audio to mono
    if len(x.shape) > 1:
        x = x.sum(axis=0)

    # Normalize audio signal
    x_norm = x / max(abs(x))

    # Calculate novelty function
    rmse = librosa.feature.rms(y=x_norm, frame_length=frame_length, hop_length=hop_length)
    rmse_diff = np.diff(rmse[0])
    novelty = np.concatenate((rmse_diff, np.array([0])))  # Add a zero at the end to maintain the same length
    novelty[novelty < 0] = 0  # We only care about increases in energy

    return novelty


def get_novelty(file):
    """Return the saved novelty array for a given audio file"""

    basename = os.path.basename(file)
    filename = basename.replace('.wav', '.npy')
    path = os.path.join(novelty_dir, filename)

    return np.load(path)


def get_ground_truth_beats(file):
    """Extract ground truth beat times for a given audio file"""

    # Get beat CSV path
    basename = os.path.basename(file)
    filename = basename.replace('.wav', '_beats.csv')
    path = os.path.join(beat_out, filename)

    onsets = []

    # Add each beat to an onset list
    with open(path) as f:
        reader = csv.DictReader(f)
        for row in reader:
            onsets.append(float(row['beat_time']))

    return np.array(onsets)  # return as numpy array


def metrics(beats, ground_truth):
    """Evaluate the onset detection model with three different metrics, given the detected onsets, and ground truth onsets"""

    # Count TPs, FPs, and FNs
    tp = fp = fn = j = 0

    # Iterate over detected beats
    for i in range(len(beats)):
        # All ground truth beats before the start of the tolerance range are false negatives
        while j < len(ground_truth) and ground_truth[j] < beats[i] - 0.05:
            j += 1
            fn += 1

        # Only a true positive if the current ground truth value is within the threshold,
        if j < len(ground_truth) and ground_truth[j] <= beats[i] + 0.05:
            j += 1
            tp += 1
        # Otherwise there were no ground truth beats within the threshold, and this onset is a false positive
        else:
            fp += 1

        i += 1

    # All remaining ground truth beats were not detected, and are false negatives
    while j < len(ground_truth):
        fn += 1
        j += 1

    precision = tp / max(tp + fp, 1)  # no division by 0
    recall = tp / max(tp + fn, 1)  # no division by 0

    f1 = 2 * (precision * recall) / max(precision + recall, 1e-6)  # no division by 0

    return precision, recall, f1


def get_sample_rate(file):
    """Get the sample rate for a given audio file from the metadata table"""

    name = os.path.basename(file)
    meta_file = os.path.join(root, "metadata.csv")
    with open(meta_file, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            if row['file'] == name:
                return float(row['sample rate'])

    return None


def evaluate_tolerance(data, labels, tolerance):
    """Calculate the average f1 score across the training data for a single tolerance value"""

    total_f1 = 0

    for i in range(len(data)):
        fs, n = data[i]
        b = labels[i]

        frames=range(len(n))
        t = librosa.frames_to_time(frames, sr=fs, hop_length=HOP_LENGTH)

        peaks, _ = signal.find_peaks(n, height=tolerance)
        p = t[peaks]

        _, _, f1 = metrics(p, b)

        total_f1 += f1

    return total_f1 / len(data)


def spectral_flux(x, hop_length, frame_length):
    """Calculate the spectral flux of an audio signal"""

    # Convert multi-channel audio to mono
    if len(x.shape) > 1:
        x = x.sum(axis=0)

    # Normalize audio signal
    x_norm = x / max(abs(x))

    # Calculate spectral flux
    stft = librosa.stft(x_norm, hop_length=hop_length, win_length=frame_length)
    diff = np.diff(np.abs(stft), axis=1)
    flux = np.sum(diff ** 2, axis=0)
    flux = np.concatenate(([0], flux))

    return flux / np.max(flux)  # normalize


def zero_crossing_rate(x, hop_length, frame_length):
    """Calculate the zero crossing rate of an audio signal"""

    # Convert multi-channel audio to mono
    if len(x.shape) > 1:
        x = x.sum(axis=0)

    # Normalize audio signal
    x_norm = x / max(abs(x))

    # Calculate zero crossing rate
    rate = librosa.feature.zero_crossing_rate(x_norm, hop_length=hop_length, frame_length=frame_length)
    diff_rate = np.diff(rate[0]) ** 2
    diff_rate = np.concatenate(([0], diff_rate))

    return diff_rate / np.max(diff_rate)  # normalize


def mfcc(x, hop_length, frame_length):
    """Calculate the MFCCs of an audio signal"""

    # Convert multi-channel audio to mono
    if len(x.shape) > 1:
        x = x.sum(axis=0)

    # Normalize audio signal
    x_norm = x / max(abs(x))

    # Calculate mfcc's
    mfccs = librosa.feature.mfcc(y=x_norm, sr=fs, hop_length=hop_length, win_length=frame_length)
    diff_mfcc = np.diff(mfccs, axis=1)
    diff_mfcc[diff_mfcc < 0] = 0
    diff_mfcc = np.concatenate((np.zeros((diff_mfcc.shape[0], 1)), diff_mfcc), axis=1)

    return diff_mfcc.T / np.max(diff_mfcc, axis=1)  # normalize


def get_sf(file):
    """Return the saved spectral flux array for a given audio file"""

    basename = os.path.basename(file)
    filename = basename.replace('.wav', '.npy')
    path = os.path.join(sf_dir, filename)

    return np.load(path)


def get_zcr(file):
    """Return the saved zero crossing rate array for a given audio file"""

    basename = os.path.basename(file)
    filename = basename.replace('.wav', '.npy')
    path = os.path.join(zcr_dir, filename)

    return np.load(path)


def get_mfcc(file):
    """Return the saved MFCC array for a given audio file"""

    basename = os.path.basename(file)
    filename = basename.replace('.wav', '.npy')
    path = os.path.join(mfcc_dir, filename)

    return np.load(path)


def evaluate_baseline(fs, feats, threshold):
    n = feats[:, 0]
    b = test_labels[i]

    frames=range(len(n))
    t = librosa.frames_to_time(frames, sr=fs, hop_length=HOP_LENGTH)

    peaks, _ = signal.find_peaks(n, height=threshold)
    return t[peaks]


def evaluate_improved(fs, feats, weights):
    n = np.dot(feats, weights)
    b = test_labels[i]

    frames=range(len(n))
    t = librosa.frames_to_time(frames, sr=fs, hop_length=HOP_LENGTH)

    peaks, _ = signal.find_peaks(n, height=0.5)
    return t[peaks]


def evaluate_all(data, labels, eval_function):
    """Retrieve the stored ground truth tempo"""
    avg_p = avg_r = avg_f1 = 0

    # Calculate average percision, recall, and F1 score across given data
    for i in range(len(data)):
        peak_times = eval_function(data[i])
        p, r, f1 = metrics(peak_times, labels[i])

        avg_p += p
        avg_r += r
        avg_f1 += f1

    avg_p /= len(test_data)
    avg_r /= len(test_data)
    avg_f1 /= len(test_data)

    return avg_p, avg_r, avg_f1


def get_ground_truth_tempo(file):
    # Get tempo CSV path
    basename = os.path.basename(file)
    filename = basename.replace('.wav', '_tempo.csv')
    path = os.path.join(tempo_out, filename)

    # Add each beat to an onset list
    with open(path) as f:
        reader = csv.DictReader(f)
        for row in reader:
            return float(row['tempo_bpm'])

    return 0


def estimate_tempo(fs, novelty, adjust=False):
    """Estimate tempo given the novelty function (and sample rate)"""

    # Autocorrelation
    ac = librosa.autocorrelate(novelty)
    lags = np.arange(len(ac))
    lag_times = lags * HOP_LENGTH / fs
    bpms = 60 / lag_times[1:]   # avoid divide by zero
    strength = ac[1:]

    # Pick beat histogram peaks
    pks, feats = signal.find_peaks(strength, height=0)
    confidence = np.stack([bpms[pks], feats['peak_heights']], axis=1)

    # Pick the highest peak (with a BPM between 40 and 300)
    confidence = confidence[np.logical_and(confidence[:, 0] > 40, confidence[:, 0] < 300)]

    # Adjust based on distribution of tempos
    if adjust:
        pdf = norm.pdf(confidence[:, 0], 131.41397849462365, 39.73982074681245)
        confidence[:, 1] *= pdf

    return confidence[np.argmax(confidence[:, 1])][0]

# %% [markdown]
# ## Data & Preprocessing
# The below cells only need to be run once to import all necessary packages, store all necessary data, and defi.

# %%
# Dataset should be placed within a data folder on the same level as this notebook
root = os.path.abspath('./data/ballroom')

# Ballroom dataset inner directories
audio_root = os.path.join(root, "BallroomData")
beats_root = os.path.join(root, "BallroomAnnotations", "ballroomBeats")
tempo_root = os.path.join(root, "BallroomAnnotations", "ballroomTempo")

# %%
audio_files = []

# Iterate through the style folders in the dataset
for style in os.listdir(audio_root):
    style_path = os.path.join(audio_root, style)

    if not os.path.isdir(style_path):
        continue

    # Add each audio file's path to the list
    for file in os.listdir(style_path):
        if not file.endswith(".wav"):
            continue

        path = os.path.join(style_path, file)
        audio_files.append(path)

# %%
# Create directories to store generated CSV files
beat_out = os.path.join(root, "beat_csv")
tempo_out = os.path.join(root, "tempo_csv")

os.makedirs(beat_out, exist_ok=True)
os.makedirs(tempo_out, exist_ok=True)

# %%
# Generate and save beat/tempo csvs
curr = 1

# Iterate through all audio files
for file in audio_files:
    filename = os.path.basename(file)
    base = filename.replace(".wav", "")

    bpm_path = os.path.join(tempo_root, base + ".bpm")
    beats_path = os.path.join(beats_root, base + ".beats")

    print(f'File {curr}/{len(audio_files)} - {filename}:')

    # -------------------------
    # TEMPO CSV
    # -------------------------
    if os.path.exists(bpm_path):
        with open(bpm_path) as f:
            bpm = float(f.read().strip())

        tempo_file = os.path.join(tempo_out, base + "_tempo.csv")

        with open(tempo_file, "w", newline="") as f:

            writer = csv.DictWriter(
                f,
                fieldnames=["file", "style", "tempo_bpm"]
            )

            writer.writeheader()
            writer.writerow({
                "file": file,
                "style": style,
                "tempo_bpm": bpm
            })

        print(f'\tTempo CSV - {tempo_file}')

    # -------------------------
    # BEAT CSV
    # -------------------------
    if os.path.exists(beats_path):
        beat_rows = []

        with open(beats_path) as f:

            for line in f:

                parts = line.strip().split()

                beat_time = float(parts[0])
                beat_id = int(parts[1])

                beat_rows.append({
                    "file": file,
                    "style": style,
                    "beat_time": beat_time,
                    "beat_id": beat_id
                })

        beat_file = os.path.join(beat_out, base + "_beats.csv")

        with open(beat_file, "w", newline="") as f:

            writer = csv.DictWriter(
                f,
                fieldnames=["file", "style", "beat_time", "beat_id"]
            )

            writer.writeheader()
            writer.writerows(beat_rows)

        print(f'\tBeat CSV - {beat_file}')

    curr += 1

print("\nPer-file beat and tempo CSVs created.")
# Out:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104314_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104314_beats.csv
# File 553/698 - Media-100614.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-100614_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-100614_beats.csv
# File 554/698 - Albums-Chrisanne2-12.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne2-12_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne2-12_beats.csv
# File 555/698 - Media-100616.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-100616_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-100616_beats.csv
# File 556/698 - Media-104316.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104316_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104316_beats.csv
# File 557/698 - Media-105020.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105020_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105020_beats.csv
# File 558/698 - Albums-Ballroom_Classics4-18.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Ballroom_Classics4-18_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Ballroom_Classics4-18_beats.csv
# File 559/698 - Albums-Ballroom_Classics4-19.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Ballroom_Classics4-19_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Ballroom_Classics4-19_beats.csv
# File 560/698 - Media-104317.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104317_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104317_beats.csv
# File 561/698 - Albums-Chrisanne2-11.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne2-11_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne2-11_beats.csv
# File 562/698 - Media-105019.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105019_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105019_beats.csv
# File 563/698 - Media-104515.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104515_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104515_beats.csv
# File 564/698 - Media-104918.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104918_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104918_beats.csv
# File 565/698 - Media-104717.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104717_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104717_beats.csv
# File 566/698 - Media-104716.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104716_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104716_beats.csv
# File 567/698 - Media-104514.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104514_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104514_beats.csv
# File 568/698 - Albums-Ballroom_Classics4-20.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Ballroom_Classics4-20_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Ballroom_Classics4-20_beats.csv
# File 569/698 - Media-105018.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105018_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105018_beats.csv
# File 570/698 - Media-104516.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104516_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104516_beats.csv
# File 571/698 - Albums-Ballroom_Magic-17.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Ballroom_Magic-17_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Ballroom_Magic-17_beats.csv
# File 572/698 - Media-105016.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105016_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105016_beats.csv
# File 573/698 - Media-104917.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104917_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104917_beats.csv
# File 574/698 - Media-104718.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104718_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104718_beats.csv
# File 575/698 - Media-104916.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104916_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104916_beats.csv
# File 576/698 - Media-105017.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105017_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105017_beats.csv
# File 577/698 - Media-103314.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103314_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103314_beats.csv
# File 578/698 - Albums-Ballroom_Magic-16.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Ballroom_Magic-16_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Ballroom_Magic-16_beats.csv
# File 579/698 - Media-105820.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105820_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105820_beats.csv
# File 580/698 - Media-104915.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104915_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104915_beats.csv
# File 581/698 - Albums-Ballroom_Magic-15.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Ballroom_Magic-15_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Ballroom_Magic-15_beats.csv
# File 582/698 - Media-103313.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103313_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103313_beats.csv
# File 583/698 - Media-105819.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105819_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105819_beats.csv
# File 584/698 - Media-105818.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105818_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105818_beats.csv
# File 585/698 - Media-103312.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103312_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103312_beats.csv
# File 586/698 - Media-105207.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105207_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105207_beats.csv
# File 587/698 - Albums-Chrisanne1-14.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne1-14_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne1-14_beats.csv
# File 588/698 - Albums-Step_By_Step-18.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Step_By_Step-18_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Step_By_Step-18_beats.csv
# File 589/698 - Media-104418.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104418_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104418_beats.csv
# File 590/698 - Media-104815.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104815_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104815_beats.csv
# File 591/698 - Media-104618.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104618_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104618_beats.csv
# File 592/698 - Media-105314.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105314_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105314_beats.csv
# File 593/698 - Media-105315.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105315_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105315_beats.csv
# File 594/698 - Albums-Chrisanne3-13.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne3-13_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne3-13_beats.csv
# File 595/698 - Media-104816.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104816_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104816_beats.csv
# File 596/698 - Media-105517.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105517_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105517_beats.csv
# File 597/698 - Albums-Chrisanne1-12.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne1-12_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne1-12_beats.csv
# File 598/698 - Media-105715.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105715_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105715_beats.csv
# File 599/698 - Media-104219.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104219_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104219_beats.csv
# File 600/698 - Media-104218.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104218_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104218_beats.csv
# File 601/698 - Albums-Chrisanne1-13.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne1-13_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne1-13_beats.csv
# File 602/698 - Media-105516.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105516_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105516_beats.csv
# File 603/698 - Media-105716.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105716_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105716_beats.csv
# File 604/698 - Albums-Chrisanne3-14.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne3-14_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne3-14_beats.csv
# File 605/698 - Media-105313.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105313_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105313_beats.csv
# File 606/698 - Albums-Chrisanne3-15.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Chrisanne3-15_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Chrisanne3-15_beats.csv
# File 607/698 - Media-105717.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105717_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105717_beats.csv
# File 608/698 - Media-103817.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103817_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103817_beats.csv
# File 609/698 - Media-103812.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103812_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103812_beats.csv
# File 610/698 - Media-103609.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103609_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103609_beats.csv
# File 611/698 - Media-104006.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104006_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104006_beats.csv
# File 612/698 - Media-104007.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104007_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104007_beats.csv
# File 613/698 - Media-103608.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103608_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103608_beats.csv
# File 614/698 - Media-103811.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103811_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103811_beats.csv
# File 615/698 - Media-104005.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104005_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104005_beats.csv
# File 616/698 - Media-103810.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103810_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103810_beats.csv
# File 617/698 - Media-105209.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105209_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105209_beats.csv
# File 618/698 - Media-104114.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104114_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104114_beats.csv
# File 619/698 - Media-103914.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103914_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103914_beats.csv
# File 620/698 - Media-105418.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105418_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105418_beats.csv
# File 621/698 - Media-105419.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105419_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105419_beats.csv
# File 622/698 - Media-104115.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104115_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104115_beats.csv
# File 623/698 - Media-103911.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103911_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103911_beats.csv
# File 624/698 - Media-105409.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105409_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105409_beats.csv
# File 625/698 - Media-105408.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105408_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105408_beats.csv
# File 626/698 - Media-104112.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104112_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104112_beats.csv
# File 627/698 - Media-103912.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103912_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103912_beats.csv
# File 628/698 - Media-103709.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103709_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103709_beats.csv
# File 629/698 - Media-103913.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103913_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103913_beats.csv
# File 630/698 - Media-104113.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104113_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104113_beats.csv
# File 631/698 - Media-103513.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103513_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103513_beats.csv
# File 632/698 - Media-105412.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105412_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105412_beats.csv
# File 633/698 - Media-103711.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103711_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103711_beats.csv
# File 634/698 - Media-103710.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103710_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103710_beats.csv
# File 635/698 - Media-103512.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103512_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103512_beats.csv
# File 636/698 - Media-103712.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103712_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103712_beats.csv
# File 637/698 - Media-105411.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105411_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105411_beats.csv
# File 638/698 - Media-105410.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105410_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105410_beats.csv
# File 639/698 - Media-103511.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103511_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103511_beats.csv
# File 640/698 - Media-103717.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103717_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103717_beats.csv
# File 641/698 - Media-103514.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103514_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103514_beats.csv
# File 642/698 - Media-103809.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103809_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103809_beats.csv
# File 643/698 - Media-104008.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-104008_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-104008_beats.csv
# File 644/698 - Media-103610.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103610_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103610_beats.csv
# File 645/698 - Media-103615.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103615_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103615_beats.csv
# File 646/698 - Media-103818.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103818_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103818_beats.csv
# File 647/698 - Media-103616.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-103616_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-103616_beats.csv
# File 648/698 - Media-106011.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106011_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106011_beats.csv
# File 649/698 - Albums-Latin_Jam4-03.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam4-03_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam4-03_beats.csv
# File 650/698 - Albums-AnaBelen_Veneo-03.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-AnaBelen_Veneo-03_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-AnaBelen_Veneo-03_beats.csv
# File 651/698 - Media-106010.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106010_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106010_beats.csv
# File 652/698 - Media-106012.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106012_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106012_beats.csv
# File 653/698 - Albums-Latin_Jam3-09.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam3-09_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam3-09_beats.csv
# File 654/698 - Albums-Cafe_Paradiso-09.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Cafe_Paradiso-09_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Cafe_Paradiso-09_beats.csv
# File 655/698 - Albums-AnaBelen_Veneo-15.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-AnaBelen_Veneo-15_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-AnaBelen_Veneo-15_beats.csv
# File 656/698 - Albums-AnaBelen_Veneo-01.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-AnaBelen_Veneo-01_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-AnaBelen_Veneo-01_beats.csv
# File 657/698 - Albums-Latin_Jam3-08.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam3-08_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam3-08_beats.csv
# File 658/698 - Albums-Pais_Tropical-11.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Pais_Tropical-11_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Pais_Tropical-11_beats.csv
# File 659/698 - Albums-Pais_Tropical-10.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Pais_Tropical-10_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Pais_Tropical-10_beats.csv
# File 660/698 - Albums-Pais_Tropical-12.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Pais_Tropical-12_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Pais_Tropical-12_beats.csv
# File 661/698 - Albums-Latin_Jam4-13.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam4-13_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam4-13_beats.csv
# File 662/698 - Albums-Fire-03.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Fire-03_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Fire-03_beats.csv
# File 663/698 - Albums-Latin_Jam2-15.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam2-15_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam2-15_beats.csv
# File 664/698 - Media-106112.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106112_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106112_beats.csv
# File 665/698 - Albums-Latin_Jam5-08.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam5-08_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam5-08_beats.csv
# File 666/698 - Media-106113.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106113_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106113_beats.csv
# File 667/698 - Albums-Latin_Jam-08.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam-08_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam-08_beats.csv
# File 668/698 - Albums-GloriaEstefan_MiTierra-01.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-GloriaEstefan_MiTierra-01_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-GloriaEstefan_MiTierra-01_beats.csv
# File 669/698 - Media-106111.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106111_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106111_beats.csv
# File 670/698 - Media-106110.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106110_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106110_beats.csv
# File 671/698 - Albums-Latin_Jam2-07.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam2-07_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam2-07_beats.csv
# File 672/698 - Albums-Fire-10.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Fire-10_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Fire-10_beats.csv
# File 673/698 - Albums-Macumba-09.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Macumba-09_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Macumba-09_beats.csv
# File 674/698 - Albums-GloriaEstefan_MiTierra-11.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-GloriaEstefan_MiTierra-11_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-GloriaEstefan_MiTierra-11_beats.csv
# File 675/698 - Albums-Latin_Jam-02.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam-02_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam-02_beats.csv
# File 676/698 - Albums-Latin_Jam2-08.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam2-08_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam2-08_beats.csv
# File 677/698 - Albums-Latin_Jam2-09.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam2-09_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam2-09_beats.csv
# File 678/698 - Albums-Macumba-12.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Macumba-12_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Macumba-12_beats.csv
# File 679/698 - Media-105611.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105611_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105611_beats.csv
# File 680/698 - Albums-GloriaEstefan_MiTierra-08.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-GloriaEstefan_MiTierra-08_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-GloriaEstefan_MiTierra-08_beats.csv
# File 681/698 - Albums-Macumba-10.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Macumba-10_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Macumba-10_beats.csv
# File 682/698 - Media-105613.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105613_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105613_beats.csv
# File 683/698 - Media-106119.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106119_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106119_beats.csv
# File 684/698 - Albums-Latin_Jam5-03.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam5-03_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam5-03_beats.csv
# File 685/698 - Media-105612.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105612_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105612_beats.csv
# File 686/698 - Albums-Macumba-11.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Macumba-11_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Macumba-11_beats.csv
# File 687/698 - Albums-Latin_Jam-14.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam-14_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam-14_beats.csv
# File 688/698 - Albums-Latin_Jam5-12.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam5-12_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam5-12_beats.csv
# File 689/698 - Albums-Latin_Jam-05.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam-05_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam-05_beats.csv
# File 690/698 - Media-105615.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105615_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105615_beats.csv
# File 691/698 - Media-105614.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-105614_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-105614_beats.csv
# File 692/698 - Albums-Pais_Tropical-09.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Pais_Tropical-09_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Pais_Tropical-09_beats.csv
# File 693/698 - Albums-Latin_Jam4-08.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam4-08_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam4-08_beats.csv
# File 694/698 - Albums-Cafe_Paradiso-10.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Cafe_Paradiso-10_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Cafe_Paradiso-10_beats.csv
# File 695/698 - Albums-Cafe_Paradiso-11.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Cafe_Paradiso-11_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Cafe_Paradiso-11_beats.csv
# File 696/698 - Media-106009.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Media-106009_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Media-106009_beats.csv
# File 697/698 - Albums-Cafe_Paradiso-12.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Cafe_Paradiso-12_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Cafe_Paradiso-12_beats.csv
# File 698/698 - Albums-Latin_Jam3-07.wav:
# 	Tempo CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/tempo_csv/Albums-Latin_Jam3-07_tempo.csv
# 	Beat CSV - /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/beat_csv/Albums-Latin_Jam3-07_beats.csv
#
# Per-file beat and tempo CSVs created.

# %%
meta_rows = []
for file in audio_files:
    dirname, filename = os.path.split(file)
    (sample_rate, x) = read(file)

    length = x.shape[-1] / sample_rate
    style = dirname.strip('/').split('/')[-1]

    meta_rows.append({
        "file": filename,
        "directory": dirname,
        "style": style,
        "sample rate": sample_rate,
        "length": length
    })

meta_file = os.path.join(root, "metadata.csv")
with open(meta_file, "w", newline="") as f:
    writer = csv.DictWriter(
        f,
        fieldnames=["file", "directory", "style", "sample rate", "length"]
    )

    writer.writeheader()
    writer.writerows(meta_rows)

print(f'Metadata CSV written at {meta_file}.')
# Out:
# Metadata CSV written at /Users/aidanmascoli/Documents/Georgia Tech/Spring 2026/MUSI 2526/Projects/Project2/data/ballroom/metadata.csv.

# %%
# Make directory for novelty functions
novelty_dir = os.path.join(root, 'novelty')
os.makedirs(novelty_dir, exist_ok=True)

# %%
# Save novelty functions to novelty dir
done = 0
for file in audio_files:
    basename = os.path.basename(file)
    (fs, x) = read(file)
    n = novelty(x, HOP_LENGTH, FRAME_LENGTH)

    filename = basename.replace(".wav", ".npy")
    with open(os.path.join(novelty_dir, filename), 'wb') as f:
        np.save(f, n)

    done += 1
    print(f'[{done}/{len(audio_files)}] Completed file "{basename}" - novelty saved as "{filename}"', flush=True)
# Out:
# [698/698] Completed file "Albums-Latin_Jam3-07.wav" - novelty saved as "Albums-Latin_Jam3-07.npy"

# %%
# Make directories for new features
sf_dir = os.path.join(root, 'spectral_flux')
zcr_dir = os.path.join(root, 'zero_crossing_rate')
mfcc_dir = os.path.join(root, 'mfcc_flux')

os.makedirs(sf_dir, exist_ok=True)
os.makedirs(zcr_dir, exist_ok=True)
os.makedirs(mfcc_dir, exist_ok=True)

# %%
# Store other features in their respective directories
done = 0
for file in audio_files:
    basename = os.path.basename(file)
    (fs, x) = read(file)
    flux = spectral_flux(x, HOP_LENGTH, FRAME_LENGTH)
    zcr = zero_crossing_rate(x, HOP_LENGTH, FRAME_LENGTH)
    mfccs = mfcc(x, HOP_LENGTH, FRAME_LENGTH)

    filename = basename.replace(".wav", ".npy")

    with open(os.path.join(sf_dir, filename), 'wb') as f:
        np.save(f, flux)
    with open(os.path.join(zcr_dir, filename), 'wb') as f:
        np.save(f, zcr)
    with open(os.path.join(mfcc_dir, filename), 'wb') as f:
        np.save(f, mfccs)

    done += 1
    print(f'[{done}/{len(audio_files)}] Completed file "{basename}" - features saved as "{filename}"', flush=True)
# Out:
# [698/698] Completed file "Albums-Latin_Jam3-07.wav" - features saved as "Albums-Latin_Jam3-07.npy"

# %% [markdown]
# ## Dataset
# To avoid using training data in our metrics, we will perform the same train-test split on the dataset that was used in training, and only use testing data throughout the rest of this notebook.

# %%
data = []
labels = []

# Consolidate features functions and ground truth beats into lists
for file in audio_files:
    fs = get_sample_rate(file)

    n = get_novelty(file)
    sf = get_sf(file)
    mfcc = get_mfcc(file)

    feats = np.stack([n, sf, mfcc[:, 0]], axis=1)
    b = get_ground_truth_beats(file)

    data.append((fs, feats))
    labels.append(b)

# Split testing and training data
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Baseline Model
#
# The baseline model simply uses an RMSE novelty function, and picks peaks to determine onsets based on that function. For the baseline model, we optimized the tolerance value on training data using gradient ascent on the F1 score to achieve the best possible accuracy.
#
# ### Pre-optimization
# Before optimization, we simply picked a tolerance value by looking at one of the novelty functions. This value was 0.03.

# %%
def eval_base_pre(data):
    return evaluate_baseline(*data, 0.03)

pre_p, pre_r, pre_f1 = evaluate_all(test_data, test_labels, eval_base_pre)

print(f'Average Precision: {pre_p:.2%}')
print(f'Average Recall: {pre_r:.2%}')
print(f'Average F1 Score: {pre_f1:.2%}')
# Out:
# Average Precision: 36.71%
# Average Recall: 66.86%
# Average F1 Score: 44.98%

# %% [markdown]
# ### Post-optimization
# Gradient ascent determined the optimal threshold value to be 0.03729. Using this value we get the following metrics:

# %%
def eval_base_post(data):
    return evaluate_baseline(*data, 0.03729)

post_p, post_r, post_f1 = evaluate_all(test_data, test_labels, eval_base_post)

print(f'Average Precision: {post_p:.2%}')
print(f'Average Recall: {post_r:.2%}')
print(f'Average F1 Score: {post_f1:.2%}')
# Out:
# Average Precision: 42.51%
# Average Recall: 60.45%
# Average F1 Score: 46.72%

# %% [markdown]
# Comparing the two models we have:

# %%
percent_p_base = np.array([pre_p, post_p]) * 100
percent_r_base = np.array([pre_r, post_r]) * 100
percent_f1_base = np.array([pre_f1, post_f1]) * 100

x = np.arange(2)  # the label locations

fig, ax = plt.subplots(layout='constrained')

p_rects = ax.bar(x, percent_p_base, 0.25, label='Precision')
ax.bar_label(p_rects, padding=3)

r_rects = ax.bar(x + 0.25, percent_r_base, 0.25, label='Recall')
ax.bar_label(r_rects, padding=3)

f1_rects = ax.bar(x + 0.5, percent_f1_base, 0.25, label='F1 Score')
ax.bar_label(f1_rects, padding=3)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percent (%)')
ax.set_title('Metrics for Naive vs Optimized Baseline Model')
ax.set_xticks(x + 0.25, ('Naive', 'Optimized'))
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 100)

# %% [markdown]
# We can see that the optimized model displays an increase in precision, but a decrease in recall. However, the overall F1 score still increases. This means that the optimizations decreased the model's sensitivity, which resulted in less of the onsets being identified, but reduced the amound of false positives along with it, increasing the overall score.
#
# Let's take a closer look at the optimized model for a single audio file. Let's listen to the audio first:

# %%
file = audio_files[178]
(fs, x) = read(file)  # load sample from dataset
Audio(x, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# This track has pretty strong percussion, so we should get pretty good performance. Let's visualize the ground truth beats over the novelty function...

# %%
n = get_novelty(file)
actual_beats = get_ground_truth_beats(file)

frames = range(len(n))
t = librosa.frames_to_time(frames, sr=fs, hop_length=HOP_LENGTH)

plt.plot(t, n)
plt.vlines(actual_beats, 0, np.max(n), colors='b')

# %% [markdown]
# And compare to our evaluated beats...

# %%
peaks, _ = signal.find_peaks(n, height=0.03729)
peak_times = t[peaks]

plt.plot(t, n)
plt.vlines(peak_times, 0, np.max(n), colors='r')

# %% [markdown]
# We can also calculate our metrics over this one file:

# %%
p, r, f1 = metrics(peak_times, actual_beats)

print(f'Precision: {p:.2%}')
print(f'Recall: {r:.2%}')
print(f'F1 Score: {f1:.2%}')
# Out:
# Precision: 48.96%
# Recall: 75.81%
# F1 Score: 59.49%

# %% [markdown]
# ## Improved Model
# The improved model works similarly, but combines multiple features in place of a single-feature novelty function. The features used are RMSE (the original novelty function), Spectral Flux, and the 0th Mel Frequency Cepstral Coefficient. These features were chosen through an extensive selection process, detailed in index.ipynb. This naive model simply added the functions for the three factors, and used a fixed threshold value of 0.5. The optimized model instead took a *weighted* sum of the features, and picked peaks using the same fixed threshold (weighting eliminated the need for a variable threshold). The weights were optimized through experimentation, as well as multi-variate gradient ascent on the F1 score.
#
# ### Pre-optimization
# When simply adding the functions together, the model performs as follows:

# %%
def eval_imp_pre(data):
    return evaluate_improved(*data, np.ones(3))

pre_p, pre_r, pre_f1 = evaluate_all(test_data, test_labels, eval_imp_pre)

print(f'Average Precision: {pre_p:.2%}')
print(f'Average Recall: {pre_r:.2%}')
print(f'Average F1 Score: {pre_f1:.2%}')
# Out:
# Average Precision: 51.41%
# Average Recall: 47.88%
# Average F1 Score: 0.4598

# %% [markdown]
# ### Post-optimization
# The original trial and error process determined that the weights (1.4, 1, 1.4) for RMSE, Spectral Flux, and MFCC 0, respectively, were the optimal starting point. Gradient descent further optimized these weights to (1.59518808, 0.89276187, 1.62964896). These optimized weights acheive the following metrics:

# %%
def eval_imp_post(data):
    weights = np.array([1.59518808, 0.89276187, 1.62964896])
    return evaluate_improved(*data, weights)

post_p, post_r, post_f1 = evaluate_all(test_data, test_labels, eval_imp_post)

print(f'Average Precision: {post_p:.2%}')
print(f'Average Recall: {post_r:.2%}')
print(f'Average F1 Score: {post_f1:.2%}')
# Out:
# Average Precision: 47.06%
# Average Recall: 63.21%
# Average F1 Score: 50.43%

# %% [markdown]
# Comparing our naive and optimized improved models, we have:

# %%
percent_p_imp = np.array([pre_p, post_p]) * 100
percent_r_imp = np.array([pre_r, post_r]) * 100
percent_f1_imp = np.array([pre_f1, post_f1]) * 100

x = np.arange(2)  # the label locations

fig, ax = plt.subplots(layout='constrained')

p_rects = ax.bar(x, percent_p_imp, 0.25, label='Precision')
ax.bar_label(p_rects, padding=3)

r_rects = ax.bar(x + 0.25, percent_r_imp, 0.25, label='Recall')
ax.bar_label(r_rects, padding=3)

f1_rects = ax.bar(x + 0.5, percent_f1_imp, 0.25, label='F1 Score')
ax.bar_label(f1_rects, padding=3)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percent (%)')
ax.set_title('Metrics for Naive vs Optimized Improved Model')
ax.set_xticks(x + 0.25, ('Naive', 'Optimized'))
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 100)

# %% [markdown]
# Here we can see the opposite scenario to our baseline model. Our precision decreased a bit from the naive model after optimizations, but the recall improved greatly. This increased the overall F1 score by nearly 5%. In this case, the overall sensitivity of the model was increased, leading to more of the actual onsets being detected, but also slightly more false positives.
#
# Let's again view this model more closely against the same single track. Here's our ground truth beats over the *new* novelty function:

# %%
n = get_novelty(file)
sf = get_sf(file)
mfcc = get_mfcc(file)

feats = np.stack([n, sf, mfcc[:, 0]], axis=1)

plt.plot(t, n)
plt.vlines(actual_beats, 0, np.max(n), colors='b')

# %% [markdown]
# And our evaluated beats:

# %%
peak_times = eval_imp_post((fs, feats))

plt.plot(t, n)
plt.vlines(peak_times, 0, np.max(n), colors='r')

# %% [markdown]
# Finally, the metrics:

# %%
p, r, f1 = metrics(peak_times, actual_beats)

print(f'Precision: {p:.2%}')
print(f'Recall: {r:.2%}')
print(f'F1 Score: {f1:.2%}')
# Out:
# Precision: 54.26%
# Recall: 82.26%
# F1 Score: 65.38%

# %% [markdown]
# Not too bad! That's an even better that average performance on the track with strong percussion, and a vast improvement in all three metrics!

# %% [markdown]
# ## Baseline vs. Improved Model Evaluation
# Now, we can finally compare our baseline model with our improved model.

# %%
percent_p = np.stack([percent_p_base, percent_p_imp])[:, 1]
percent_r = np.stack([percent_r_base, percent_r_imp])[:, 1]
percent_f1 = np.stack([percent_f1_base, percent_f1_imp])[:, 1]

x = np.arange(2)  # the label locations

fig, ax = plt.subplots(layout='constrained')

p_rects = ax.bar(x, percent_p, 0.25, label='Precision')
ax.bar_label(p_rects, padding=3)

r_rects = ax.bar(x + 0.25, percent_r, 0.25, label='Recall')
ax.bar_label(r_rects, padding=3)

f1_rects = ax.bar(x + 0.5, percent_f1, 0.25, label='F1 Score')
ax.bar_label(f1_rects, padding=3)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percent (%)')
ax.set_title('Metrics for Optimized Baseline vs Improved Model')
ax.set_xticks(x + 0.25, ('Baseline', 'Improved'))
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 100)

# %% [markdown]
# And in this case, we can see an improvement in all three statistics! This is because while our model optimizations involved an optimization of the model's overall sensitivity, which typically causes a tradeoff between a model's precision and accuracy. But since our improved model takes a different approach entirely, in the optimized versions of both models, we don't see that tradeoff at all, and rather an improvement in all three metrics!
#
# # Tempo Estimation
# Let's move on to the extension task! In order to estimate tempo we simply used autocorrelation on the improved novelty function and picked peaks from the beat histogram.
#
# ## Dataset
# We will need to redo the test/train split, using the improved novelty function and retrieving the tempo as the ground truth label.

# %%
data = []
labels = []

# Consolidate calculate new novelty functions save them as well as ground truth tempos into lists
for file in audio_files:
    fs = get_sample_rate(file)

    n = get_novelty(file)
    sf = get_sf(file)
    mfcc = get_mfcc(file)

    feats = np.stack([n, sf, mfcc[:, 0]], axis=1)
    improved = np.dot(feats, weights)
    tempo = get_ground_truth_tempo(file)

    data.append((fs, improved))
    labels.append(tempo)

# Split testing and training data
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Pre-optimization
# If we simply pick the peak from the beat histogram with the highest strength, here is how our model performs. As stated in index.ipynb, we will allow an 8% error margin for tempo estimations, as specified in the MIREX tempo estimation standard.

# %%
count = 0

est_tempos = []
actual_tempos = []

for i in range(len(test_data)):
    est_tempo = estimate_tempo(*test_data[i])
    actual_tempo = test_labels[i]

    est_tempos.append(est_tempo)
    actual_tempos.append(actual_tempo)

    if 0.92 <= est_tempo / actual_tempo <= 1.08:  # 8% tolerance threshold
        count += 1

print(f'Tempo correct for {count}/{len(test_data)} tracks ({count / len(test_data):.2%})')
# Out:
# Tempo correct for 51/140 tracks (36.43%)

# %% [markdown]
# We can also plot the estimated vs actual tempos on a scatter plot, to see where our errors are coming from. We will also draw lines y=0.5x and y=2x, as datapoints close to these lines have simply doubled or halved the correct tempo.

# %%
plt.scatter(est_tempos, actual_tempos)

x1 = np.arange(300)
x2 = np.arange(150)

y1 = 1 / 2 * x1
y2 = 2 * x2

plt.plot(x1, x1)
plt.plot(x1, y1)
plt.plot(x2, y2)

plt.ylabel("Actual tempo (BPM)")
plt.xlabel("Estimated tempo (BPM)")
plt.title("Predicted vs Actual Tempo")

# %% [markdown]
# We can see many of the incorrect estimations fall on the tempo doubling/tempo halving lines. We can also see that many of the estimated values for these errors fall on extreme ends of the reasonable tempo scale.
#
# ## Post-optimization
# If we adjust the strength of the peaks in our beat histogram to more heavily weight more common tempo values (as determined by a normal distribution and the mean/standard deviation of tempos in the training data), we can make a small improvement to this model.

# %%
count = 0

est_tempos = []
actual_tempos = []

for i in range(len(test_data)):
    est_tempo = estimate_tempo(*test_data[i], True)
    actual_tempo = test_labels[i]

    est_tempos.append(est_tempo)
    actual_tempos.append(actual_tempo)

    if 0.92 <= est_tempo / actual_tempo <= 1.08:  # 8% tolerance threshold
        count += 1

print(f'Tempo correct for {count}/{len(test_data)} tracks ({count / len(test_data):.2%})')
# Out:
# Tempo correct for 64/140 tracks (45.71%)

# %% [markdown]
# That's an almost 10% improvement to our accuracy! If we plot the estimated vs actual tempos again, we will see the following.

# %%
plt.scatter(est_tempos, actual_tempos)

x1 = np.arange(200)
x2 = np.arange(100)

y1 = 1 / 2 * x1
y2 = 2 * x2

plt.plot(x1, x1)
plt.plot(x1, y1)
plt.plot(x2, y2)

plt.ylabel("Actual tempo (BPM)")
plt.xlabel("Estimated tempo (BPM)")
plt.title("Predicted vs Actual Tempo")

# %% [markdown]
# Most of our doubling and halving errors are gone! The main errors seem to be whatever those clumps in between the lines are. These likely come from more complicated subdivisions, or just an imperfection of the novelty function itself.
